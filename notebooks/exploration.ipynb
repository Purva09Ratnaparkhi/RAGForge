# %% [markdown]
# # RAGForge — Exploration Notebook
#
# Use this notebook for debugging and testing individual components.
#
# ## Setup
# Make sure you're in the project root and have installed dependencies:
# ```bash
# pip install -r requirements.txt
# ```

# %%
import sys
sys.path.insert(0, '..')

from config.settings import *
print(f'Project root: {ROOT_DIR}')
print(f'Data dir: {DATA_DIR}')
print(f'Embedding model: {EMBEDDING_MODEL}')

# %% [markdown]
# ## 1. Test PDF Detection

# %%
from src.extraction.pdf_detector import detect_pdf_type

# Place a test PDF in data/raw/ and update the path
# result = detect_pdf_type(RAW_PDF_DIR / 'sample.pdf')
# print(f'Type: {result.pdf_type}, Complex: {result.is_complex_layout}')

# %% [markdown]
# ## 2. Test Extraction Pipeline

# %%
from src.extraction.pipeline import ExtractionPipeline

# pipeline = ExtractionPipeline()
# docs = pipeline.run(RAW_PDF_DIR / 'sample.pdf')
# print(f'Extracted {len(docs)} documents')
# for doc in docs[:3]:
#     print(f'  Page {doc.metadata["page"]}: {doc.page_content[:100]}...')

# %% [markdown]
# ## 3. Test Chunking

# %%
from src.chunking.smart_chunker import chunk_documents

# chunks = chunk_documents(docs)
# print(f'Produced {len(chunks)} chunks')
# for chunk in chunks[:3]:
#     print(f'  Chunk {chunk.metadata["chunk_index"]}: {chunk.page_content[:80]}...')

# %% [markdown]
# ## 4. Test Embeddings

# %%
from src.embeddings.bge_embedder import BGEEmbedder

# embedder = BGEEmbedder()
# vec = embedder.embed_query('What is attention?')
# print(f'Vector dim: {len(vec)}')

# %% [markdown]
# ## 5. Test LLM Factory

# %%
from src.generation.llm_factory import get_llm_with_fallback

# llm = get_llm_with_fallback()
# response = llm.invoke('Hello, how are you?')
# print(response.content)

# %% [markdown]
# ## 6. Test RAG Agent Graph

# %%
# from src.agents.rag_agent import build_rag_graph
# graph = build_rag_graph()
# result = graph.invoke({'query': 'What is the main contribution of this paper?',
#                        'query_type': '', 'rewritten_queries': [],
#                        'retrieved_docs': [], 'reranked_docs': [],
#                        'compressed_docs': [], 'answer': '',
#                        'guardrail_result': {}, 'context_str': '',
#                        'history_str': '', 'messages': []})
# print(result['answer'])
